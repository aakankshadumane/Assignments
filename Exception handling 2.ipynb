# %%
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
exception class is inherited in custom class to inherit the properties. 
The working of exceptions is defined in exception class.

# %%
# Q2. Write a python program to print Python Exception Hierarchy.
import inspect
print("The class hierarchy for built-in exceptions is:")
inspect.getclasstree(inspect.getmro(Exception))
def classtree(cls, indent=0):
    print('.' * indent, cls.__name__)
    for subcls in cls.__subclasses__():
        classtree(subcls, indent + 3)
classtree(Exception)
# Out:
# The class hierarchy for built-in exceptions is:
#  Exception
# ... TypeError
# ...... FloatOperation
# ...... MultipartConversionError
# ... StopAsyncIteration
# ... StopIteration
# ... ImportError
# ...... ModuleNotFoundError
# ......... PackageNotFoundError
# ......... PackageNotFoundError
# ...... ZipImportError
# ... OSError
# ...... ConnectionError
# ......... BrokenPipeError
# ......... ConnectionAbortedError
# ......... ConnectionRefusedError
# ......... ConnectionResetError
# ............ RemoteDisconnected
# ...... BlockingIOError
# ...... ChildProcessError
# ...... FileExistsError
# ...... FileNotFoundError
# ...... IsADirectoryError
# ...... NotADirectoryError
# ...... InterruptedError
# ......... InterruptedSystemCall
# ...... PermissionError
# ...... ProcessLookupError
# ...... TimeoutError
# ...... UnsupportedOperation
# ...... herror
# ...... gaierror
# ...... timeout
# ...... Error
# ......... SameFileError
# ...... SpecialFileError
# ...... ExecError
# ...

# %%
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
ArithmeticError class in Python include:

OverFlowError
ZeroDivisionError
FloatingPointError

# %%
5/0   #Arithmetic Error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
1.2-1.0
# Out:
# 0.19999999999999996

# %%
0.19999999999999996 + 1.0
# Out:
# 1.2

# %%
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.
LookupError Exception is the Base class for errors raised when something can’t be found. 
The base class for the exceptions that are raised when a key or index 
used on a mapping or sequence is invalid

# %%
foo = [22,58,166,44,36]
print(foo[5])  #Index error example
# indexes are counted from 0 to 4 so 5 is not present
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 foo = [22,58,166,44,36]
# ----> 2 print(foo[5])
#
# IndexError: list index out of range

# %%
d = {'a':55,'b':87}
d['c']  #key error example
# key named 'c' does not exists in dictionary
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 d = {'a':55,'b':87}
# ----> 2 d['c']
#
# KeyError: 'c'

# %%
# Q5. Explain ImportError. What is ModuleNotFoundError?
Import error occurs when module is not present or misspelled.

# %%
from newclass import newmodule
# there is no such class or module existing hence the error Module not found
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 from newclass import newmodule
#
# ModuleNotFoundError: No module named 'newclass'

# %%
# Q6. List down some best practices for exception handling in python.
1. Use try,catch blocks
2. Specific exception is catch first and then base class exception is used in catch
3. Log exceptions for future reference
4. raise custom error for more information
